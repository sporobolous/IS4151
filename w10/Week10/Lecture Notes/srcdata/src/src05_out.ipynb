# %%
import math

import pandas as pd

import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn import metrics
import scipy.stats as stats

import statsmodels.api as sm

# %%
df = pd.read_csv('../data/colleges.csv', index_col=0)
df
# Out:
#                          Type  MedianSAT  AcceptanceRate  \
# School
# Amherst              Lib Arts       1315            0.22
# Barnard              Lib Arts       1220            0.53
# Bates                Lib Arts       1240            0.36
# Berkeley           University       1176            0.37
# Bowdoin              Lib Arts       1300            0.24
# Brown              University       1281            0.24
# Bryn Mawr            Lib Arts       1255            0.56
# Cal Tech           University       1400            0.31
# Carleton             Lib Arts       1300            0.40
# Carnegie Mellon    University       1225            0.64
# Claremont McKenna    Lib Arts       1260            0.36
# Colby                Lib Arts       1200            0.46
# Colgate              Lib Arts       1258            0.38
# Columbia           University       1268            0.29
# Cornell            University       1280            0.30
# Davisdson            Lib Arts       1230            0.36
# Duke               University       1310            0.25
# Georgetown         University       1278            0.24
# Grinnell             Lib Arts       1244            0.67
# Hamilton             Lib Arts       1215            0.38
# Harvard            University       1370            0.18
# Haverford            Lib Arts       1285            0.35
# Johns Hopkins      University       1290            0.48
# Middlebury           Lib Arts       1255            0.25
# MIT                University       1357            0.30
# Mount Holyoke        Lib Arts       1200            0.61
# Northwestern       University       1230            0.47
# Oberlin              Lib Arts       1247            0.54
# Occidental           Lib Arts       1170            0.49
# Pomona               Lib Arts       1320            0.33
# Princeton          University       1340            0.17
# Rice               University       1327            0.24
# Smith                Lib Arts       1195            0.57
# Stanford           University       1370            0.18
# Swarthnore           Lib Arts       1310            0.24
# U Michigan         University       1195            0.60
# U of Chicago       University       1300            0.45
# U of Rochester     University       1155            0.56
# U Pennsylvania     University       1280            0.41
# U Va               University       1218            0.37
# UCLA               University       1142            0.43
# UNC                University       1109            0.32
# Vassar               Lib Arts       1287            0.43
# Washington U (MO)  University       1225            0.54
# Washinton and Lee    Lib Arts       1234            0.29
# Wellesley            Lib Arts       1250            0.49
# Wesleyan (CT)        Lib Arts       1290            0.35
# Williams             Lib Arts       1336            0.28
# Yale               University       1350            0.19
#
#                    ExpendituresPerStudent  Top10PercentHS  GraduationPercent
# School
# Amherst                             26636              85                 93
# Barnard                             17653              69                 80
# Bates                               17554              58                 88
# Berkeley                            23665              95                 68
# Bowdoin                             25703              78                 90
# Brown                               24201              80                 90
# Bryn Mawr                           18847              70                 84
# Cal Tech                           102262              98                 75
# Carleton                            15904              75                 80
# Carnegie Mellon                     33607              52                 77
# Claremont McKenna                   20377              68                 74
# Colby                               18872              52                 84
# Colgate                             17520              61                 85
# Columbia                            45879              78                 90
# Cornell                             37137              85                 83
# Davisdson                           17721              77                 89
# Duke                                39504              91                 91
# Georgetown                          23115              79                 89
# Grinnell                            22301              65                 73
# Hamilton                            20722              51                 85
# Harvard                             46918              90                 90
# Haverford                           19418              71                 87
# Johns Hopkins                       45460              69                 86
# Middlebury                          24718              65                 92
# MIT                                 56766              95                 86
# Mount Holyoke                       23358              47                 83
# Northwestern                        28851              77                 82
# Oberlin                             23591              64                 77
# Occidental                          20192              54                 72
# Pomona                              26668              79                 80
# Princeton                           48123              89                 93
# Rice                                26730              85                 88
# Smith                               25271              65                 87
# Stanford                            61921              92                 88
# Swarthnore                          27487              78                 88
# U Michigan                          21853              71                 77
# U of Chicago                        38937              74                 73
# U of Rochester                      38597              52                 73
# U Pennsylvania                      30882              87                 86
# U Va                                19365              77                 88
# UCLA                                26859              96                 61
# UNC                                 19684              82                 73
# Vassar                              20179              53                 84
# Washington U (MO)                   39883              71                 76
# Washinton and Lee                   17998              61                 78
# Wellesley                           27879              76                 86
# Wesleyan (CT)                       19948              73                 91
# Williams                            23772              86                 93
# Yale                                52468              90                 93

# %%
df = df.drop('Type', axis=1)

df.corr(method='pearson')
# Out:
#                         MedianSAT  AcceptanceRate  ExpendituresPerStudent  \
# MedianSAT                1.000000       -0.601902                0.572742
# AcceptanceRate          -0.601902        1.000000               -0.284254
# ExpendituresPerStudent   0.572742       -0.284254                1.000000
# Top10PercentHS           0.503468       -0.609721                0.505782
# GraduationPercent        0.564147       -0.550378                0.042504
#
#                         Top10PercentHS  GraduationPercent
# MedianSAT                     0.503468           0.564147
# AcceptanceRate               -0.609721          -0.550378
# ExpendituresPerStudent        0.505782           0.042504
# Top10PercentHS                1.000000           0.138613
# GraduationPercent             0.138613           1.000000

# %%
# scikit learn
independent_variables = df.drop('GraduationPercent', axis=1)

x = independent_variables.values
y = df['GraduationPercent'].values

lr = LinearRegression(fit_intercept = True)
lr.fit(x, y)
y_pred = lr.predict(x)

print('Coefficients = ', lr.coef_)
# Out:
# Coefficients =  [ 7.20062848e-02 -2.48592318e+01 -1.35649860e-04 -1.62764489e-01]

# %%
print('Intercept = ', lr.intercept_)
# Out:
# Intercept =  17.920955870648484

# %%
print('R^2 = ', lr.score(x, y))
# Out:
# R^2 =  0.5344260406481331

# %%
print('Root MSE = ', math.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# Root MSE =  5.030218801347664

# %%
# statsmodels
x = independent_variables
y = df['GraduationPercent']

x2 = sm.add_constant(x)
ols = sm.OLS(y, x2)
est = ols.fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      GraduationPercent   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                     12.63
# Date:                Tue, 25 Mar 2025   Prob (F-statistic):           6.33e-07
# Time:                        04:28:25   Log-Likelihood:                -148.69
# No. Observations:                  49   AIC:                             307.4
# Df Residuals:                      44   BIC:                             316.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     17.9210     24.557      0.730      0.469     -31.571      67.413
# MedianSAT                  0.0720      0.018      4.004      0.000       0.036       0.108
# AcceptanceRate           -24.8592      8.315     -2.990      0.005     -41.617      -8.101
# ExpendituresPerStudent    -0.0001   6.59e-05     -2.057      0.046      -0.000   -2.77e-06
# Top10PercentHS            -0.1628      0.079     -2.051      0.046      -0.323      -0.003
# ==============================================================================
# Omnibus:                        1.954   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.376   Jarque-Bera (JB):                1.833
# Skew:                          -0.450   Prob(JB):                        0.400
# Kurtosis:                       2.706   Cond. No.                     1.12e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
